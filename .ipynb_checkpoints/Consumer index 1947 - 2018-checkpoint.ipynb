# %%
import fred
from config import API_KEY

# %%
fred.key(API_KEY)

# %%
fred.category()
# Out:
# {'categories': [{'id': 0, 'name': 'Categories', 'parent_id': 0}]}

# %%
fred.series('CPIAUCSL')
# Out:
# {'realtime_start': '2018-12-03',
#  'realtime_end': '2018-12-03',
#  'seriess': [{'id': 'CPIAUCSL',
#    'realtime_start': '2018-12-03',
#    'realtime_end': '2018-12-03',
#    'title': 'Consumer Price Index for All Urban Consumers: All Items',
#    'observation_start': '1947-01-01',
#    'observation_end': '2018-10-01',
#    'frequency': 'Monthly',
#    'frequency_short': 'M',
#    'units': 'Index 1982-1984=100',
#    'units_short': 'Index 1982-1984=100',
#    'seasonal_adjustment': 'Seasonally Adjusted',
#    'seasonal_adjustment_short': 'SA',
#    'last_updated': '2018-11-14 07:51:02-06',
#    'popularity': 96,
# ...

# %%
data = fred.observations('CPIAUCSL')

# %%
import pandas as pd
consumer_index_df = pd.DataFrame.from_dict(data)

# %%
consumer_index_df.head(500)
# Out:
#     realtime_start realtime_end observation_start observation_end units  \
# 0       2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# 1       2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# 2       2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# 3       2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# 4       2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# 5       2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# 6       2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# 7       2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# 8       2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# 9       2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# 10      2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# 11      2018-12-03   2018-12-03        1600-01-01      9999-12-31   lin
# ...

# %%
consumer_index_df.to_csv("/Users/titus/Desktop/Homework1/data_dashboard/Project-3")
